# %%
# !pip install -r requirements
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements'

# %%
import os
os.environment['KAGGLE_CONFIG_DIR']= '.'

# %%
import train
train.main()

import visualize
visualize.plot_curves()
visualize.plot_confusion_matrix()

import predict
predict.predict()
